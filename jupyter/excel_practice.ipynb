# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
docdir = '../static/'
docfile = 'codecommit3.01-3.15.xlsx'
sheetname = '项目'
sheet = pd.read_excel(docdir+docfile, sheet_name=sheetname)

# %%
sheet.head()
# Out:
#    项目归属事业部  二级部门 三级部门  项目ID          项目名称  项目类型 项目负责人（项目经理）  提交总人数  提交总次数  \
# 0  智能运营事业部   研发部  NaN    98       微服务管控平台  产品项目         雷中雄      2      4
# 1  智能运营事业部   研发部  NaN   101    流程引擎能力中台系统  产品项目         孙德重      4     16
# 2  智能运营事业部  项目七部  NaN   233      重庆移动代维管理  系统项目        刘嘉nw      7     73
# 3  智能运营事业部  项目五部  NaN   294  联通总部在线咨询管理应用  系统项目         张绍东      1   7421
# 4  智能运营事业部  项目五部  NaN   296    辽宁移动手机办公门户  系统项目         梁文昊      1     18
#
#       新增行数     删除行数  修改文件总数  总变更行数（新增行数+删除行数）
# 0       41       26       6                67
# 1  8530398  8529313     108          17059711
# 2    21019     2240     332             23259
# 3  9769883  2201217   68028          11971100
# 4     8268    11135      73             19403

# %%
sheet[(sheet['项目归属事业部'] == '智能运营事业部') & (sheet['项目类型'] == '系统项目') & (sheet['项目ID'] == '991')]
# Out:
# Empty DataFrame
# Columns: [项目归属事业部, 二级部门, 三级部门, 项目ID, 项目名称, 项目类型, 项目负责人（项目经理）, 提交总人数, 提交总次数, 新增行数, 删除行数, 修改文件总数, 总变更行数（新增行数+删除行数）]
# Index: []
