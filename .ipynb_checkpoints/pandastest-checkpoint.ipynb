# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
# 让notebook宽屏显示
from IPython.display import display, HTML
display(HTML('<style>.container{width:100% !important;}</style>'))
# Out:
# <style>.container{width:100% !important;}</style>

# %%
pd.set_option('display.max_rows',None)

# %%
xls_file = "./static/效能数据统计分析_12.11.xlsx"

# %%
pdresult = {}

# %%
Xlsx = pd.ExcelFile(xls_file)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
frame = pd.read_excel(Xlsx,'按人员统计代码提交分析')

# %%
def assessment(attendv=0,repov=0,codcommitv=0):
    assess_total = 0
    repo_total = 0
    #参与项目评分
    attentscore = {1:3,2:5,3:7,4:9,5:11,6:13,7:16,8:19,9:22,10:25,11:28}
    if 0<attendv<12:
        assess_total = attentscore[attendv]
    elif attendv>=12:
        assess_total = 30
        
    #参与代码库评分
    if 1<repov<=5:
        assess_total += 3
    elif 5<repov<=10:
        assess_total += 8
    elif 10<repov<=15:
        assess_total += 12
    elif 15<repov<=20:
        assess_total += 19
    elif 20<repov<=30:
        assess_total += 25
    elif repov>30:
        assess_total += 30

    #参与代码库评分
    if codcommitv>1 and codcommitv<=10000:
        assess_total += 3
    elif codcommitv>10001 and codcommitv<=30000:
        assess_total += 8
    elif codcommitv>30001 and codcommitv<=40000:
        assess_total += 13
    elif codcommitv>40001 and codcommitv<=50000:
        assess_total += 18
    elif codcommitv>50001 and codcommitv<=60000:
        assess_total += 23
    elif codcommitv>60001 and codcommitv<=70000:
        assess_total += 28
    elif codcommitv>70001 and codcommitv<=80000:
        assess_total += 32
    elif codcommitv>80001 and codcommitv<=100000:
        assess_total += 35
    elif codcommitv>100001 and codcommitv<=150000:
        assess_total += 37
    elif codcommitv>150001 and codcommitv<=200000:
        assess_total += 38
    elif codcommitv>2000001 and codcommitv<=500000:
        assess_total += 39
    elif codcommitv>500000:
        assess_total += 40

    return assess_total

# %%
df = pd.DataFrame()

for name,value in frame.groupby(frame['姓名']):
    newvalue = value.drop_duplicates(subset='代码库')
    
    info = newvalue.iloc[0]
    prosum = newvalue['项目ID'].unique()
    sum_attend = len(prosum)
    sum_repo = len(newvalue['代码库'])
    sum_code_commit = sum(newvalue['提交行数'])
    
    temp = [name,info.iloc[1],info.iloc[2],assessment(sum_attend,sum_repo,sum_code_commit),sum_attend,sum_repo,sum_code_commit]
    df.loc[0]=temp

print(df)
# Out:
# ['丁炜', '技术中台支撑部', '02-后台开发', 16, 2, 5, 28013]
# ['丁靖', '技术中台支撑部', '02-后台开发', 31, 1, 1, 63676]
# ['于天哲', '智能运营事业部', '02-后台开发', 38, 6, 13, 33750]
# ['于显', '数字化运营事业部', '02-后台开发', 48, 2, 4, 1217094]
# ['于缓缓', '云网运营事业部', '02-后台开发', 25, 4, 7, 17069]
# ['付世平', '数字化运营事业部', '02-后台开发', 50, 3, 6, 90827]
# ['付晶', '数字化运营事业部', '01-部门经理、主管', 62, 6, 15, 131074]
# ['代伟', '数字化运营事业部', '02-后台开发', 55, 3, 7, 857213]
# ['任小云', '智能运营事业部', '02-后台开发', 59, 5, 6, 16729996]
# ['任晓琼', '云网运营事业部', '02-后台开发', 48, 2, 3, 968328]
# ['何钰', '智能运营事业部', '02-后台开发', 19, 1, 6, 10841]
# ['倪明达', '技术中台支撑部', '03-前台开发', 53, 2, 8, 1309126]
# ['兰倩', '智能运营事业部', '02-后台开发', 45, 3, 4, 97936]
# ['冯中强', '数字化运营事业部', '02-后台开发', 63, 5, 11, 776044]
# ['冯川', '数字化运营事业部', '01-项目管理', 6, 1, 3, 232443]
# ['冯秋平', '智能运营事业部', '02-后台开发', 14, 1, 2, 23776]
# ['冷其祥', '云网运营事业部', '02-后台开发', 57, 4, 9, 3593754]
# ['凌冰', '智能运营事业部', '02-后台开发', 78, 9, 18, 103131]
# ['刘一', '智能运营事业部', '03-前台开发', 49, 12, 17, 296572]
# ['刘世长', '智能运营事业部', '01-项目管理', 43, 1, 2, 148299]
# ['刘伟', '智能运营事业部', '02-后台开发', 73, 1, 77, 6116729]
# ['刘克雄', '智能运营事业部', '01-软件架构', 26, 2, 3, 41747]
# ['刘子腾', '数字化运营事业部', '02-后台开发', 42, 5, 9, 55214]
# ['刘子龙', '数字化运营事业部', '01-部门总经理、副总经理、总监', 9, 1, 5, 5]
# ['刘宇', '智能运营事业部', '03-前台开发', 72, 9, 11, 187539]
# ['刘帅', '云网运营事业部', '02-后台开发', 46, 2, 2, 160371]
# ['刘开英', '数字化运营事业部', '01-实施', 9, 1, 2, 1795]
# ['刘志昂', '数字化运营事业部', '03-前台开发', 59, 5, 8, 838103]
# ['刘文凯', '智能运营事业部', '02-后台开发', 18, 3, 5, 23783]
# ['刘新宇', '智能运营事业部', '03-前台开发', 13, 2, 6, 418974]
# ['刘星', '数字化运营事业部', '03-前台开发', 27, 8, 10, 493574]
# ['刘春辉', '云网运营事业部', '02-后台开发', 72, 6, 16, 1247351]
# ['刘松浩', '数字化运营事业部', '02-后台开发', 66, 4, 17, 153600]
# ['刘植鑫', '云网运营事业部', '02-后台开发', 50, 3, 3, 8338741]
# ['刘欢', '智能运营事业部', '02-后台开发', 6, 1, 1, 454]
# ['刘正和', '云网运营事业部', '02-后台开发', 18, 3, 4, 29407]
# ['刘浩', '智能运营事业部', '02-后台开发', 44, 1, 4, 170797]
# ['刘炜', '智能运营事业部', '02-后台开发', 26, 2, 6, 38222]
# ['刘玉琴', '云网运营事业部', '02-后台开发', 28, 3, 3, 46366]
# ['刘皓', '数字化运营事业部', '02-后台开发', 8, 2, 5, 235825]
# ['刘贺', '数字化运营事业部', '02-后台开发', 10, 3, 4, 205591]
# ['刘越', '数字化运营事业部', '02-后台开发', 19, 1, 3, 35371]
# ['刘锦新', '通信运营事业部', '01-部门总经理、副总经理、总监', 6, 1, 1, 19]
# ['刘香', '数字化运营事业部', '02-后台开发', 49, 4, 4, 130810]
# ['包祺', '智能运营事业部', '02-后台开发', 75, 8, 20, 144813]
# ['单国庆', '技术中台支撑部', '02-后台开发', 9, 1, 3, 8883]
# ['单汝英', '智能运营事业部', '02-后台开发', 3, 1, 1, 353666]
# ['卢丹丹', '云网运营事业部', '02-后台开发', 46, 2, 2, 165953]
# ['卢日剑', '数字化运营事业部', '02-后台开发', 56, 4, 12, 99747]
# ['史腾飞', '数字化运营事业部', '02-后台开发', 50, 3, 7, 84663]
# ['叶杨典', '智能运营事业部', '03-前台开发', 8, 2, 5, 426427]
# ['司广楠', '智能运营事业部', '02-后台开发', 59, 3, 13, 573345]
# ['吕明澳', '云网运营事业部', '02-后台开发', 10, 3, 5, 434106]
# ['吴克非', '智能运营事业部', '02-后台开发', 51, 1, 6, 1910720]
# ['吴清', '数字化运营事业部', '02-后台开发', 21, 2, 8, 28295]
# ['吴锋', '通信运营事业部', '02-后台开发', 37, 2, 16, 37192]
# ['周全', '数字化运营事业部', '02-后台开发', 72, 3, 21, 1644614]
# ['周志红', '智能运营事业部', '02-后台开发', 6, 1, 2, 271093]
# ['周星晨', '云网运营事业部', '02-后台开发', 23, 3, 7, 20475]
# ['周腾晓', '数字化运营事业部', '03-前台开发', 32, 5, 6, 32335]
# ['周鑫', '智能运营事业部', '02-后台开发', 6, 1, 1, 6812]
# ['周鹏', '智能运营事业部', '03-前台开发', 74, 10, 15, 120549]
# ['唐松林', '智能运营事业部', '02-后台开发', 70, 2, 27, 3162703]
# ['唐永林', '智能运营事业部', '02-后台开发', 72, 3, 24, 11976731]
# ['唐照岚', '智能运营事业部', '02-后台开发', 11, 1, 1, 27074]
# ['夏梦洋', '数字化运营事业部', '02-后台开发', 55, 4, 10, 164577]
# ['夏秋爽', '数字化运营事业部', '02-后台开发', 25, 6, 12, 214899]
# ['姚依钧', '云网运营事业部', '02-后台开发', 16, 1, 1, 30093]
# ['姚大波', '云网运营事业部', '02-后台开发', 59, 5, 9, 4988264]
# ['姜忆然', '数字化运营事业部', '02-后台开发', 87, 11, 18, 2442361]
# ['姬永康', '数字化运营事业部', '02-后台开发', 51, 1, 9, 517558]
# ['孙义星', '数字化运营事业部', '02-后台开发', 76, 5, 22, 1938251]
# ['孙伟', '智能运营事业部', '02-后台开发', 14, 1, 2, 24484]
# ['孙志爱', '技术中台支撑部', '03-前台开发', 57, 4, 10, 968332]
# ['孙显清', '数字化运营事业部', '02-后台开发', 40, 1, 1, 121286]
# ['孙未蔺', '云网运营事业部', '02-后台开发', 40, 2, 2, 78531]
# ['孙瑞冰', '智能运营事业部', '02-后台开发', 46, 1, 3, 1241582]
# ['孙磊', '数字化运营事业部', '01-项目管理', 46, 1, 2, 5094999]
# ['孙闯', '数字化运营事业部', '02-后台开发', 43, 1, 3, 133334]
# ['孟华', '智能运营事业部', '02-后台开发', 39, 1, 8, 68627]
# ['孟志欣', '数字化运营事业部', '03-前台开发', 59, 5, 10, 543410]
# ['宁文文', '智能运营事业部', '02-后台开发', 37, 5, 10, 49168]
# ['安东红', '数字化运营事业部', '02-后台开发', 48, 2, 4, 2877315]
# ['安伟伟', '数字化运营事业部', '03-前台开发', 78, 8, 17, 7031465]
# ['安巧云', '云网运营事业部', '03-前台开发', 46, 1, 2, 639802]
# ['宋佳强', '数字化运营事业部', '02-后台开发', 55, 3, 6, 1293699]
# ['宋宝华', '智能运营事业部', '01-项目管理', 48, 2, 2, 5640011]
# ['宋宪文', '云网运营事业部', '02-后台开发', 46, 1, 2, 1208372]
# ['宋科', '智能运营事业部', '02-后台开发', 68, 4, 18, 4099501]
# ['封晓娜', '智能运营事业部', '02-后台开发', 11, 2, 3, 7698]
# ['尤广明', '数字化运营事业部', '02-后台开发', 54, 3, 14, 88765]
# ['尹国锋', '数字化运营事业部', '02-后台开发', 50, 3, 10, 93662]
# ['左桢', '云网运营事业部', '02-后台开发', 40, 1, 1, 139564]
# ['师文生', '数字化运营事业部', '02-后台开发', 6, 1, 1, 158]
# ['常沙', '智能运营事业部', '02-后台开发', 28, 3, 9, 34896]
# ['常磊', '云网运营事业部', '02-后台开发', 40, 1, 1, 101340]
# ['庞广胜', '数字化运营事业部', '02-后台开发', 6, 1, 3, 245891]
# ['康业飞', '智能运营事业部', '02-后台开发', 26, 2, 2, 43796]
# ['廖斌', '智能运营事业部', '02-后台开发', 57, 2, 14, 2113699]
# ['张丹丹', '云网运营事业部', '02-后台开发', 45, 2, 3, 115642]
# ['张亚克', '技术中台支撑部', '02-后台开发', 16, 2, 5, 12061]
# ['张佳庆', '通信运营事业部', '02-后台开发', 6, 1, 1, 1013]
# ['张俊凯', '数字化运营事业部', '01-项目管理', 46, 1, 3, 3812068]
# ['张劲松', '智能运营事业部', '02-后台开发', 48, 2, 4, 2402035]
# ['张华勇', '智能运营事业部', '02-后台开发', 47, 11, 16, 275140]
# ['张宜川', '智能运营事业部', '02-后台开发', 40, 1, 1, 105066]
# ['张岩', '智能运营事业部', '02-后台开发', 9, 1, 2, 8927]
# ['张扇兵', '智能运营事业部', '03-前台开发', 45, 3, 3, 97787]
# ['张文豪', '数字化运营事业部', '02-后台开发', 27, 5, 6, 24007]
# ['张明阳', '数字化运营事业部', '03-前台开发', 57, 4, 9, 4460689]
# ['张昱禾', '智能运营事业部', '02-后台开发', 73, 1, 36, 4151525]
# ['张显生', '智能运营事业部', '02-后台开发', 3, 1, 1, 0]
# ['张林', '云网运营事业部', '02-后台开发', 48, 2, 2, 865015]
# ['张毅', '云网运营事业部', '03-前台开发', 40, 4, 4, 67511]
# ['张浩', '云网运营事业部', '02-后台开发', 10, 3, 3, 447564]
# ['张玲', '数字化运营事业部', '02-后台开发', 56, 5, 6, 142728]
# ['张磊', '智能运营事业部', '02-后台开发', 68, 4, 18, 9334294]
# ['张继伟', '数字化运营事业部', '02-后台开发', 53, 2, 8, 16273478]
# ['张继红', '技术中台支撑部', '03-前台开发', 53, 2, 8, 2694203]
# ['张迪', '智能运营事业部', '02-后台开发', 60, 6, 11, 94680]
# ['张通', '智能运营事业部', '02-后台开发', 48, 2, 4, 832184]
# ['张鹏', '数字化运营事业部', '02-后台开发', 55, 3, 7, 13732138]
# ['彭勇俊', '数字化运营事业部', '02-后台开发', 47, 4, 4, 82683]
# ['徐亚男', '数字化运营事业部', '02-后台开发', 6, 1, 1, 92]
# ['徐宇辰', '数字化运营事业部', '02-后台开发', 54, 5, 7, 82707]
# ['景发强', '云网运营事业部', '02-后台开发', 8, 2, 3, 310318]
# ['曹晨阳', '数字化运营事业部', '02-后台开发', 61, 7, 8, 115795]
# ['曹泽天', '云网运营事业部', '02-后台开发', 40, 1, 1, 132493]
# ['曹鹏', '智能运营事业部', '01-项目管理', 41, 2, 9, 68012]
# ['曹龙', '数字化运营事业部', '02-后台开发', 16, 2, 5, 26508]
# ['曾建', '智能运营事业部', '02-后台开发', 24, 1, 2, 42707]
# ['朱冬妹', '通信运营事业部', '03-前台开发', 23, 3, 6, 26268]
# ['朱圣伟', '数字化运营事业部', '02-后台开发', 44, 1, 4, 157732]
# ['朱文龙', '云网运营事业部', '02-后台开发', 70, 5, 16, 2268348]
# ['朱晓旭', '智能运营事业部', '02-后台开发', 11, 2, 4, 320]
# ['朱曼然', '云网运营事业部', '02-后台开发', 6, 1, 1, 967]
# ['李云飞', '数字化运营事业部', '02-后台开发', 21, 4, 11, 414840]
# ['李亭亭', '云网运营事业部', '02-后台开发', 43, 1, 1, 810709]
# ['李伟', '数字化运营事业部', '01-部门经理、主管', 70, 5, 16, 3351554]
# ['李冉', '通信运营事业部', '03-前台开发', 6, 1, 3, 425190]
# ['李卫昊', '智能运营事业部', '02-后台开发', 18, 3, 5, 11237]
# ['李哲琪', '数字化运营事业部', '02-后台开发', 48, 2, 5, 1063066]
# ['李学伟', '智能运营事业部', '02-后台开发', 6, 1, 2, 262860]
# ['李宏泰', '数字化运营事业部', '02-后台开发', 15, 3, 6, 284535]
# ['李帅', '智能运营事业部', '01-软件架构', 81, 9, 20, 5341458]
# ['李庆磊', '通信运营事业部', '02-后台开发', 43, 2, 2, 90070]
# ['李建业', '数字化运营事业部', '01-部门经理、主管', 13, 2, 6, 379949]
# ['李彬彬', '数字化运营事业部', '02-后台开发', 8, 2, 3, 237768]
# ['李忠应', '数字化运营事业部', '02-后台开发', 42, 3, 5, 79637]
# ['李想', '通信运营事业部', '03-前台开发', 61, 6, 9, 706387]
# ['李文华', '智能运营事业部', '03-前台开发', 29, 6, 6, 12268]
# ['李昆', '云网运营事业部', '02-后台开发', 48, 2, 5, 3610611]
# ['李晶', '云网运营事业部', '02-后台开发', 54, 5, 5, 1224724]
# ['李智', '云网运营事业部', '02-后台开发', 47, 5, 9, 60748]
# ['李杰超', '智能运营事业部', '01-部门经理、主管', 14, 1, 2, 20638]
# ['李林', '智能运营事业部', '03-前台开发', 95, 19, 23, 1330788]
# ['李梦威', '数字化运营事业部', '02-后台开发', 68, 7, 12, 2070603]
# ['李江林', '智能运营事业部', '01-部门经理、主管', 9, 1, 2, 170]
# ['李泽', '云网运营事业部', '02-后台开发', 8, 2, 2, 231115]
# ['李海波', '数字化运营事业部', '03-前台开发', 10, 3, 5, 306325]
# ['李涛', '云网运营事业部', '01-部门经理、主管', 52, 4, 4, 834455]
# ['李淇沅', '云网运营事业部', '03-前台开发', 53, 2, 10, 2349841]
# ['李灵华', '数字化运营事业部', '02-后台开发', 89, 13, 20, 668669]
# ['李石磊', '数字化运营事业部', '02-后台开发', 48, 3, 3, 159359]
# ['李磊', '智能运营事业部', '02-后台开发', 19, 3, 15, 459441]
# ['李禹霖', '数字化运营事业部', '02-后台开发', 50, 3, 3, 839138]
# ['李胜奇', '云网运营事业部', '01-软件架构', 48, 2, 2, 1908909]
# ['李茂', '通信运营事业部', '02-后台开发', 33, 1, 14, 45268]
# ['李薇薇', '智能运营事业部', '02-后台开发', 98, 11, 33, 993989]
# ['李路路', '智能运营事业部', '02-后台开发', 6, 1, 1, 82]
# ['李静', '云网运营事业部', '02-后台开发', 53, 2, 8, 657015]
# ['李香港', '数字化运营事业部', '02-后台开发', 10, 3, 4, 255452]
# ['李龙', '数字化运营事业部', '02-后台开发', 57, 2, 14, 11872599]
# ['杨中华', '智能运营事业部', '02-后台开发', 61, 4, 14, 2699482]
# ['杨坤', '智能运营事业部', '02-后台开发', 6, 1, 1, 36]
# ['杨学文', '智能运营事业部', '02-后台开发', 6, 1, 1, 1257]
# ['杨帆', '数字化运营事业部', '01-实施', 9, 1, 2, 3165]
# ['杨常珩', '云网运营事业部', '02-后台开发', 48, 2, 2, 573561]
# ['杨庆龙', '智能运营事业部', '02-后台开发', 28, 3, 5, 45015]
# ['杨建国', '数字化运营事业部', '02-后台开发', 23, 5, 11, 245082]
# ['杨文棚', '云网运营事业部', '02-后台开发', 50, 3, 4, 1738140]
# ['杨昊', '短信业务支撑部', '02-后台开发', 63, 5, 12, 2708436]
# ['杨晓刚', '数字化运营事业部', '02-后台开发', 17, 4, 8, 390137]
# ['杨林辉', '数字化运营事业部', '02-后台开发', 40, 1, 1, 148746]
# ['杨洋', '数字化运营事业部', '02-后台开发', 24, 1, 2, 43244]
# ['杨浩', '数字化运营事业部', '02-后台开发', 63, 8, 12, 76846]
# ['杨涛', '智能运营事业部', '02-后台开发', 50, 10, 28, 296844]
# ['杨超亚', '数字化运营事业部', '02-后台开发', 17, 4, 6, 249290]
# ['杨青', '通信运营事业部', '02-后台开发', 31, 2, 8, 48669]
# ['林川', '云网运营事业部', '02-后台开发', 13, 3, 4, 411]
# ['林师雄', '云网运营事业部', '02-后台开发', 9, 1, 2, 2478]
# ['柳延臣', '智能运营事业部', '02-后台开发', 68, 7, 14, 1009510]
# ['柴栋民', '智能运营事业部', '02-后台开发', 6, 1, 1, 1120]
# ['柴荣荣', '数字化运营事业部', '03-前台开发', 19, 5, 6, 249142]
# ['栗晓龙', '智能运营事业部', '01-部门经理、主管', 28, 3, 8, 36429]
# ['梁潇', '数字化运营事业部', '03-前台开发', 57, 4, 6, 619154]
# ['樊凯', '数字化运营事业部', '02-后台开发', 35, 1, 1, 70726]
# ['武斌旭', '智能运营事业部', '02-后台开发', 50, 2, 6, 108505]
# ['毕鹏', '云网运营事业部', '02-后台开发', 45, 3, 4, 99210]
# ['江承兴', '云网运营事业部', '02-后台开发', 10, 3, 3, 201256]
# ['沈列辉', '云网运营事业部', '02-后台开发', 52, 3, 7, 103480]
# ['游成浪', '云网运营事业部', '02-后台开发', 50, 3, 4, 784393]
# ['游超', '智能运营事业部', '02-后台开发', 6, 1, 3, 259545]
# ['潘佳玲', '数字化运营事业部', '02-后台开发', 16, 2, 4, 12169]
# ['王世玉', '数字化运营事业部', '02-后台开发', 45, 2, 5, 111605]
# ['王世豪', '数字化运营事业部', '03-前台开发', 9, 1, 2, 7093]
# ['王丽欣', '云网运营事业部', '02-后台开发', 55, 4, 6, 178798]
# ['王亮', '数字化运营事业部', '02-后台开发', 57, 4, 9, 1210129]
# ['王伟', '技术中台支撑部', '02-后台开发', 24, 2, 19, 316734]
# ['王俊峰', '云网运营事业部', '02-后台开发', 46, 1, 2, 874250]
# ['王冠超', '数字化运营事业部', '02-后台开发', 46, 1, 3, 5523677]
# ['王凯凯', '智能运营事业部', '02-后台开发', 36, 2, 2, 67339]
# ['王娟', '数字化运营事业部', '02-后台开发', 52, 4, 5, 551230]
# ['王小园', '数字化运营事业部', '02-后台开发', 16, 2, 4, 13369]
# ['王峰', '数字化运营事业部', '02-后台开发', 64, 7, 9, 599732]
# ['王建强', '数字化运营事业部', '02-后台开发', 10, 3, 4, 444869]
# ['王张钱', '智能运营事业部', '02-后台开发', 57, 4, 8, 1733269]
# ['王志喜', '云网运营事业部', '02-后台开发', 43, 2, 4, 86342]
# ['王扬', '数字化运营事业部', '01-软件架构', 72, 6, 16, 3054410]
# ['王昊鹏', '数字化运营事业部', '01-实施', 11, 2, 2, 433]
# ['王晓青', '数字化运营事业部', '02-后台开发', 11, 2, 3, 8662]
# ['王晨', '智能运营事业部', '02-后台开发', 6, 1, 4, 216808]
# ['王朝', '数字化运营事业部', '02-后台开发', 65, 6, 12, 1174219]
# ['王永华', '数字化运营事业部', '02-后台开发', 11, 1, 1, 25000]
# ['王洪超', '智能运营事业部', '02-后台开发', 66, 1, 24, 199977]
# ['王浩', '智能运营事业部', '02-后台开发', 100, 16, 49, 1187657]
# ['王磊', '智能运营事业部', '02-后台开发', 48, 2, 5, 687066]
# ['王秋爽', '数字化运营事业部', '02-后台开发', 33, 1, 43, 299446]
# ['王耀夫', '智能运营事业部', '01-软件架构', 75, 8, 16, 144589]
# ['王胜', '智能运营事业部', '02-后台开发', 100, 15, 40, 1293582]
# ['王英旭', '数字化运营事业部', '02-后台开发', 57, 4, 9, 2476938]
# ['王路娜', '云网运营事业部', '03-前台开发', 48, 3, 3, 165170]
# ['王金树', '云网运营事业部', '02-后台开发', 11, 2, 2, 4963]
# ['王鑫', '技术中台支撑部', '03-前台开发', 50, 2, 7, 148998]
# ['王阳阳', '数字化运营事业部', '03-前台开发', 24, 7, 9, 452835]
# ['王震新', '数字化运营事业部', '01-软件架构', 45, 3, 5, 82547]
# ['王鹏达', '数字化运营事业部', '02-后台开发', 74, 4, 21, 1721484]
# ['田东飞', '云网运营事业部', '02-后台开发', 45, 4, 9, 60233]
# ['田贵方', '云网运营事业部', '02-后台开发', 34, 1, 3, 69476]
# ['申光远', '数字化运营事业部', '02-后台开发', 46, 1, 4, 1162003]
# ['盛昊楠', '智能运营事业部', '02-后台开发', 60, 6, 19, 66926]
# ['石贝贝', '数字化运营事业部', '02-后台开发', 59, 3, 12, 2221192]
# ['石雪营', '智能运营事业部', '03-前台开发', 25, 4, 7, 17450]
# ['祖晓阳', '云网运营事业部', '02-后台开发', 55, 3, 6, 2583246]
# ['秦建光', '云网运营事业部', '02-后台开发', 18, 3, 4, 22213]
# ['程世朝', '数字化运营事业部', '01-部门经理、主管', 92, 9, 37, 2638984]
# ['窦豫宁', '智能运营事业部', '02-后台开发', 3, 1, 1, 225160]
# ['米子宽', '数字化运营事业部', '02-后台开发', 43, 1, 1, 2924791]
# ['米灵丽', '数字化运营事业部', '03-前台开发', 71, 8, 13, 544101]
# ['罗洋', '智能运营事业部', '03-前台开发', 8, 2, 4, 410187]
# ['罗阳', '智能运营事业部', '02-后台开发', 21, 1, 1, 48657]
# ['翟佳元', '数字化运营事业部', '02-后台开发', 52, 7, 9, 60244]
# ['肖冬林', '数字化运营事业部', '02-后台开发', 57, 4, 6, 1461508]
# ['肖函', '数字化运营事业部', '02-后台开发', 11, 1, 1, 13240]
# ['肖森森', '数字化运营事业部', '02-后台开发', 50, 3, 5, 1252875]
# ['胡勇', '云网运营事业部', '02-后台开发', 8, 2, 2, 378486]
# ['胡天奇', '云网运营事业部', '01-软件架构', 45, 2, 2, 112153]
# ['胡宸赫', '技术中台支撑部', '02-后台开发', 40, 1, 1, 129283]
# ['胡建平', '智能运营事业部', '03-前台开发', 15, 3, 7, 478135]
# ['胡浩', '智能运营事业部', '02-后台开发', 26, 1, 1, 52040]
# ['胡超', '云网运营事业部', '02-后台开发', 8, 2, 2, 247851]
# ['苏梓越', '通信运营事业部', '03-前台开发', 6, 1, 1, 33]
# ['苏阳', '云网运营事业部', '03-前台开发', 68, 7, 13, 1038160]
# ['苗洁', '数字化运营事业部', '02-后台开发', 56, 5, 8, 124075]
# ['葛志伟', '数字化运营事业部', '02-后台开发', 95, 15, 22, 735287]
# ['董占鹏', '云网运营事业部', '02-后台开发', 40, 1, 1, 127834]
# ['蒋小东', '数字化运营事业部', '02-后台开发', 59, 5, 10, 682693]
# ['蒯路帆', '智能运营事业部', '02-后台开发', 6, 1, 1, 6539]
# ['蔡亮', '云网运营事业部', '02-后台开发', 48, 2, 2, 689934]
# ['蔡宝山', '数字化运营事业部', '02-后台开发', 43, 2, 2, 96807]
# ['蔡春博', '智能运营事业部', '02-后台开发', 55, 5, 11, 77684]
# ['蔡翔', '智能运营事业部', '02-后台开发', 55, 3, 10, 1547035]
# ['褚永锋', '云网运营事业部', '02-后台开发', 50, 3, 5, 1458223]
# ['谢亚峰', '数字化运营事业部', '02-后台开发', 23, 3, 6, 17398]
# ['谭红波', '智能运营事业部', '02-后台开发', 26, 1, 1, 59620]
# ['贾冬冬', '数字化运营事业部', '02-后台开发', 34, 4, 24, 219488]
# ['贾跃廷', '数字化运营事业部', '03-前台开发', 48, 2, 5, 2674541]
# ['赵亚丽', '云网运营事业部', '02-后台开发', 6, 1, 2, 485221]
# ['赵加恒', '数字化运营事业部', '02-运维', 6, 1, 1, 154]
# ['赵博龙', '云网运营事业部', '02-后台开发', 59, 4, 12, 193083]
# ['赵唐波', '智能运营事业部', '02-后台开发', 8, 2, 3, 255376]
# ['赵坤', '智能运营事业部', '02-后台开发', 63, 7, 20, 69287]
# ['赵大亮', '通信运营事业部', '01-部门经理、主管', 62, 2, 19, 183636]
# ['赵子骁', '数字化运营事业部', '02-后台开发', 14, 1, 4, 15965]
# ['赵宁波', '数字化运营事业部', '02-后台开发', 6, 1, 1, 3118]
# ['赵宇智', '智能运营事业部', '01-项目管理', 3, 1, 1, 0]
# ['赵小蓉', '数字化运营事业部', '01-软件架构', 46, 1, 2, 2168839]
# ['赵燕', '数字化运营事业部', '03-前台开发', 37, 10, 15, 304476]
# ['赵立朋', '数字化运营事业部', '02-后台开发', 14, 1, 6, 4568]
# ['赵鹏', '数字化运营事业部', '02-后台开发', 47, 3, 5, 105472]
# ['赵龙', '技术中台支撑部', '02-后台开发', 19, 1, 2, 31331]
# ['邢亚辉', '数字化运营事业部', '02-后台开发', 19, 1, 2, 32092]
# ['邰佳威', '智能运营事业部', '02-后台开发', 45, 4, 6, 67035]
# ['邱一鸣', '数字化运营事业部', '02-后台开发', 60, 5, 15, 102709]
# ['邱朝铎', '智能运营事业部', '01-实施', 44, 1, 5, 181571]
# ['邹红军', '智能运营事业部', '02-后台开发', 6, 1, 1, 861]
# ['郎全生', '智能运营事业部', '02-后台开发', 50, 3, 3, 871013]
# ['郑大方', '数字化运营事业部', '02-后台开发', 52, 3, 6, 139493]
# ['郑波', '智能运营事业部', '01-部门经理、主管', 57, 4, 10, 908036]
# ['郭东阁', '云网运营事业部', '02-后台开发', 6, 1, 1, 4752]
# ['郭培斌', '数字化运营事业部', '02-后台开发', 39, 4, 12, 46610]
# ['郭杨', '智能运营事业部', '02-后台开发', 81, 8, 27, 111134]
# ['郭浩然', '数字化运营事业部', '02-后台开发', 38, 1, 1, 81659]
# ['郭航', '数字化运营事业部', '02-后台开发', 41, 2, 6, 61590]
# ['郭菲菲', '云网运营事业部', '03-前台开发', 48, 2, 4, 5797402]
# ['郭鸽鸽', '数字化运营事业部', '03-前台开发', 71, 9, 15, 142775]
# ['金婷', '云网运营事业部', '02-后台开发', 61, 6, 8, 5783361]
# ['钱雅凡', '数字化运营事业部', '02-后台开发', 48, 3, 5, 191929]
# ['铁长龙', '技术中台支撑部', '02-后台开发', 26, 2, 10, 37246]
# ['闫海胜', '智能运营事业部', '02-后台开发', 76, 5, 27, 21955657]
# ['阴玉刚', '云网运营事业部', '01-部门总经理、副总经理、总监', 34, 1, 2, 67467]
# ['陈园园', '云网运营事业部', '01-实施', 6, 1, 1, 4156]
# ['陈孔林', '技术中台支撑部', '02-后台开发', 52, 2, 14, 90629]
# ['陈强', '云网运营事业部', '02-后台开发', 13, 3, 4, 5218]
# ['陈志刚', '数字化运营事业部', '02-后台开发', 50, 3, 5, 786322]
# ['陈思良', '云网运营事业部', '03-前台开发', 53, 2, 8, 963188]
# ['陈明辉', '智能运营事业部', '02-后台开发', 52, 1, 11, 138525]
# ['陈晓杰', '数字化运营事业部', '02-后台开发', 57, 4, 7, 3362430]
# ['陈杰', '智能运营事业部', '02-后台开发', 48, 2, 5, 2168096]
# ['陈洪兵', '云网运营事业部', '02-后台开发', 3, 1, 1, 301144]
# ['陈涛', '数字化运营事业部', '02-后台开发', 18, 3, 6, 6044]
# ['陈贺龙', '数字化运营事业部', '02-后台开发', 42, 3, 3, 73672]
# ['陈锐', '智能运营事业部', '03-前台开发', 13, 2, 6, 408498]
# ['陈雷', '云网运营事业部', '02-后台开发', 52, 4, 4, 1225078]
# ['陈飞', '数字化运营事业部', '02-后台开发', 48, 2, 4, 1054242]
# ['雷中雄', '智能运营事业部', '02-后台开发', 60, 9, 32, 23699]
# ['韦壮壮', '数字化运营事业部', '02-后台开发', 87, 11, 19, 2874472]
# ['韩子鸣', '智能运营事业部', '02-后台开发', 13, 3, 5, 3392]
# ['饶栋梁', '智能运营事业部', '02-后台开发', 38, 1, 2, 74368]
# ['马卓', '智能运营事业部', '02-后台开发', 46, 1, 2, 800504]
# ['马广旭', '智能运营事业部', '02-后台开发', 61, 5, 11, 150415]
# ['马建', '云网运营事业部', '02-后台开发', 46, 2, 2, 196149]
# ['马彬', '智能运营事业部', '02-后台开发', 42, 7, 10, 47057]
# ['高乾', '数字化运营事业部', '01-实施', 43, 1, 1, 1479024]
# ['高亚斌', '技术中台支撑部', '02-后台开发', 13, 2, 7, 400781]
# ['高亮', '数字化运营事业部', '02-后台开发', 59, 3, 15, 3585078]
# ['高厦', '数字化运营事业部', '01-项目管理', 46, 1, 2, 1300557]
# ['高天宇', '数字化运营事业部', '02-后台开发', 18, 3, 5, 16882]
# ['高志航', '智能运营事业部', '02-后台开发', 48, 6, 14, 51627]
# ['高文佳', '数字化运营事业部', '02-后台开发', 68, 4, 19, 4208951]
# ['高永波', '数字化运营事业部', '02-后台开发', 53, 2, 6, 1418496]
# ['魏龙飞', '云网运营事业部', '02-后台开发', 53, 2, 6, 644213]
# ['麻超', '数字化运营事业部', '02-后台开发', 17, 4, 7, 451637]
# ['黄斌', '数字化运营事业部', '01-实施', 3, 1, 1, 1]
# ['黄春苗', '数字化运营事业部', '02-后台开发', 44, 8, 24, 271483]
# ['黄锦盛', '数字化运营事业部', '02-后台开发', 19, 3, 11, 250192]
# ['黄鹏', '云网运营事业部', '02-后台开发', 14, 1, 2, 25195]
# ['龚乐思', '云网运营事业部', '02-后台开发', 48, 3, 3, 152769]
