# %%
from khan_dev_data import *
# pdb.set_trace()  # 设置断点
dname = '云网运营事业部'

pro_type = (2,1)   #1为系统项目，2为产品项目
pd_data = []

# %%
for ptype in pro_type:

	print(project_type[ptype],":")
	project_list = get_project_by_dept(project_type[ptype],dname)
# Out:
# 产品项目 :
# 系统项目 :

# %%
project_list
# Out:
# [('云网运营事业部',
#   188,
#   'oasinterface_nx',
#   '宁夏集中操作维护OAS 接口服务提供',
#   '田东飞',
#   '未开始',
#   None,
#   None,
#   None),
#  ('云网运营事业部', 209, 'jzwh', '宁夏核心网基站维护工具', '田东飞', '未开始', None, None, None),
#  ('云网运营事业部', 246, 'ultra-log', '卫通项目二期', '肖森森', '未开始', None, None, None),
#  ('云网运营事业部',
#   334,
#   'U-XJYD-YWZC',
#   '新疆移动政企运维支撑系统',
#   '王志喜',
#   '进行中',
#   '新疆',
#   '移动',
#   '新疆移动'),
#  ('云网运营事业部',
#   397,
#   'U-LTJT-TLXY',
#   '联通集团网研院天猎星云业务分析系统',
#   '王金树',
#   '进行中',
#   '集团',
#   '联通',
#   '集团联通'),
#  ('云网运营事业部',
#   695,
#   'U-LTJT-TSGZ',
#   '联通集团网研院用户级感知评价及预警平台',
#   '王金树',
#   '进行中',
#   '集团',
#   '联通',
#   '集团联通'),
#  ('云网运营事业部',
#   700,
#   'U-LTJT-TXYJ',
#   '联通集团网研院移网投诉分析支撑系统',
#   '王金树',
#   '进行中',
#   '集团',
#   '联通',
#   '集团联通'),
#  ('云网运营事业部',
#   839,
#   'U-GD-CNMP',
#   '广播电视集团核心网运维工作台',
#   '陈思良',
#   '已完成',
#   '集团',
#   '广电',
#   '集团广电'),
#  ('云网运营事业部',
#   988,
#   'U-GZYD-SJWG',
#   '贵州移动数据网管系统',
#   '杨新',
#   '维保阶段',
#   '贵州',
#   '移动',
#   '贵州移动'),
#  ('云网运营事业部',
#   989,
#   'U-YDJT-GBAMS',
#   '移动集团核心网工作台主动监测系统',
#   '李远',
#   '进行中',
#   '集团',
#   '移动',
#   '集团移动'),
#  ('云网运营事业部',
#   990,
#   'U-HBYD-CNMP',
#   '河北移动核心网运维工作台',
#   '刘龙',
#   '进行中',
#   '河北',
#   '移动',
#   '河北移动'),
#  ('云网运营事业部',
#   992,
#   'U-GZYD-SJGXPT',
#   '贵州移动数据共享平台',
#   '杨新',
#   '维保阶段',
#   '贵州',
#   '移动',
#   '贵州移动'),
#  ('云网运营事业部',
#   998,
#   'U-GZYD-CDNGZT',
#   '贵州移动CDN运维工作台',
#   '陈雪梅',
#   '进行中',
#   '贵州',
#   '移动',
#   '贵州移动'),
#  ('云网运营事业部',
#   999,
#   'U-GZDX-YWZHWG',
#   '贵州电信业务平台综合网管',
#   '陈亚琴',
#   '维保阶段',
#   '贵州',
#   '电信',
#   '贵州电信'),
#  ('云网运营事业部',
#   1006,
#   'U-GXYD-IPDIW',
#   '广西移动IP运维工作台',
#   '彭新勇',
#   '进行中',
#   '广西',
#   '移动',
#   '广西移动'),
#  ('云网运营事业部',
#   1011,
#   'U-GXYD-IPNMS',
#   '广西移动IP网管',
#   '彭新勇',
#   '维保阶段',
#   '广西',
#   '移动',
#   '广西移动'),
#  ('云网运营事业部',
#   1017,
#   'U-GXYD-SCREEN',
#   '广西移动监控可视化大屏',
#   '邓蔓',
#   '进行中',
#   '广西',
#   '移动',
#   '广西移动'),
#  ('云网运营事业部',
#   1019,
#   'U-GXYD-PONNMS',
#   '广西移动PON性能分析系统',
#   '彭新勇',
#   '进行中',
#   '广西',
#   '移动',
#   '广西移动'),
#  ('云网运营事业部',
#   1023,
#   'U-GXYD-IQA',
#   '广西移动家宽用户画像',
#   '邓蔓',
#   '进行中',
#   '广西',
#   '移动',
#   '广西移动'),
#  ('云网运营事业部',
#   1025,
#   'U-HIYD-IPDIW',
#   '海南移动IP运维工作台',
#   '王英洁',
#   '进行中',
#   '海南',
#   '移动',
#   '海南移动'),
#  ('云网运营事业部',
#   1027,
#   'U-GSYD-ITDIW',
#   '甘肃移动IT运维工作台',
#   '顾斌',
#   '进行中',
#   '甘肃',
#   '移动',
#   '甘肃移动'),
#  ('云网运营事业部',
#   1031,
#   'U-YNYD-IPDIW',
#   '云南移动IP运维工作台',
#   '李国华',
#   '进行中',
#   '云南',
#   '移动',
#   '云南移动'),
#  ('云网运营事业部',
#   1036,
#   'U-YNYD-SJWG',
#   '云南移动数据网OMC系统',
#   '李国华',
#   '维保阶段',
#   '云南',
#   '移动',
#   '云南移动'),
#  ('云网运营事业部',
#   1040,
#   'U-YNYD-CNMP',
#   '云南移动配置管理系统',
#   '吴梓良',
#   '进行中',
#   '云南',
#   '移动',
#   '云南移动'),
#  ('云网运营事业部',
#   1042,
#   'U-YNYD-JZXN',
#   '云南移动家宽性能分析系统',
#   '陈海林1',
#   '进行中',
#   '云南',
#   '移动',
#   '云南移动'),
#  ('云网运营事业部',
#   1044,
#   'U-HBYD-IPDIW',
#   '湖北移动IP运维工作台',
#   '陈源',
#   '进行中',
#   '湖北',
#   '移动',
#   '湖北移动'),
#  ('云网运营事业部', 1047, 'U-HBYD-SJWG', '湖北移动数据网管', '陈源', '进行中', '湖北', '移动', '湖北移动'),
#  ('云网运营事业部',
#   1049,
#   'U-HBYD-JZXN',
#   '湖北移动家宽性能分析系统',
#   '陈源',
#   '进行中',
#   '湖北',
#   '移动',
#   '湖北移动'),
#  ('云网运营事业部',
#   1050,
#   'U-SNYD-SJWG',
#   '陕西移动数据网管',
#   '卫金龙',
#   '维保阶段',
#   '陕西',
#   '移动',
#   '陕西移动'),
#  ('云网运营事业部',
#   1051,
#   'U-SXYD-IPDIW',
#   '山西移动IP运维工作台',
#   '李峥',
#   '进行中',
#   '山西',
#   '移动',
#   '山西移动'),
#  ('云网运营事业部',
#   1052,
#   'U-SXYD-CNMP',
#   '山西移动核心网运维工作台',
#   '李峥',
#   '进行中',
#   '山西',
#   '移动',
#   '山西移动'),
#  ('云网运营事业部',
#   1056,
#   'U-SXYD-SJWG',
#   '山西移动数据网管',
#   '李峥',
#   '维保阶段',
#   '山西',
#   '移动',
#   '山西移动'),
#  ('云网运营事业部',
#   1060,
#   'U-XJDX-YWZDH',
#   '新疆电信运维自动化平台',
#   '马玲丽',
#   '维保阶段',
#   '新疆',
#   '电信',
#   '新疆电信'),
#  ('云网运营事业部',
#   1063,
#   'U-NXYD-ITOMC',
#   '宁夏移动ITOMC系统',
#   '吴涛',
#   '进行中',
#   '宁夏',
#   '移动',
#   '宁夏移动'),
#  ('云网运营事业部',
#   1064,
#   'U-NXYD-JZCZ',
#   '宁夏移动集中操作维护系统',
#   '吴涛',
#   '进行中',
#   '宁夏',
#   '移动',
#   '宁夏移动'),
#  ('云网运营事业部',
#   1066,
#   'U-CQYD-PZGL',
#   '重庆移动局数据配置管理系统',
#   '金雯',
#   '进行中',
#   '重庆',
#   '移动',
#   '重庆移动'),
#  ('云网运营事业部',
#   1071,
#   'U-NMDX-SJGXPT',
#   '内蒙古电信数据共享平台',
#   '杨新',
#   '维保阶段',
#   '内蒙古',
#   '电信',
#   '内蒙古电信'),
#  ('云网运营事业部',
#   1073,
#   'U-LNYD-JZXN',
#   '辽宁移动集中性能管理系统',
#   '杜洋',
#   '进行中',
#   '辽宁',
#   '移动',
#   '辽宁移动'),
#  ('云网运营事业部',
#   1075,
#   'U-LNYD-YWZDH',
#   '辽宁移动运维自动化系统',
#   '曲直',
#   '进行中',
#   '辽宁',
#   '移动',
#   '辽宁移动'),
#  ('云网运营事业部',
#   1076,
#   'U-DXJT-ZNWG',
#   '电信集团智能网管',
#   '张淼伟',
#   '维保阶段',
#   '北京',
#   '电信',
#   '电信集团'),
#  ('云网运营事业部',
#   1078,
#   'U-BJYD-WJZZL',
#   '北京移动伪基站源头治理系统',
#   '黄剑锋',
#   '维保阶段',
#   '北京',
#   '移动',
#   '北京移动'),
#  ('云网运营事业部',
#   1081,
#   'U-BJYD-CNMP',
#   '北京移动核心网运维工作台',
#   '李远',
#   '进行中',
#   '北京',
#   '移动',
#   '北京移动'),
#  ('云网运营事业部',
#   1084,
#   'U-HBYD-IPMAN',
#   '湖北移动IP地址管理',
#   '陈源',
#   '进行中',
#   '湖北',
#   '移动',
#   '湖北移动'),
#  ('云网运营事业部',
#   1085,
#   'U-HIYD-IPMAN',
#   '海南移动IP地址管理',
#   '王英洁',
#   '进行中',
#   '海南',
#   '移动',
#   '海南移动'),
#  ('云网运营事业部',
#   1086,
#   'U-GXYD-IPMAN',
#   '广西移动IP地址管理',
#   '彭新勇',
#   '进行中',
#   '广西',
#   '移动',
#   '广西移动'),
#  ('云网运营事业部',
#   1155,
#   'U-HNYD-IPDIW',
#   '湖南移动IP运维工作台',
#   '王志防',
#   '进行中',
#   '湖南',
#   '移动',
#   '湖南移动'),
#  ('云网运营事业部',
#   1165,
#   'U-HIYD-CNMP',
#   '海南移动核心网运维工作台',
#   '王英洁',
#   '进行中',
#   '海南',
#   '移动',
#   '海南移动'),
#  ('云网运营事业部',
#   1194,
#   'U-LTJT-CNDL',
#   '2023年中国联通研究院算网网络专线',
#   '王金树',
#   '进行中',
#   '中国',
#   '联通',
#   '研究院'),
#  ('云网运营事业部',
#   1196,
#   'U-ZGGD-IPDIW',
#   '中国广电IP运维工作台',
#   '孙一',
#   '未开始',
#   '中国',
#   '广电',
#   '中国广电'),
#  ('云网运营事业部',
#   1198,
#   'U-LNYD-ZLGL',
#   '辽宁移动质量管理中心项目',
#   '杜洋',
#   '未开始',
#   '辽宁',
#   '移动',
#   '辽宁移动'),
#  ('云网运营事业部',
#   1274,
#   'U-YDJT-CNMP',
#   '中国移动集团核心网工作台支撑服务项目 (集团)',
#   '左战辉',
#   '未开始',
#   '北京',
#   '移动',
#   '中国移动'),
#  ('云网运营事业部',
#   1275,
#   'U-FJYD-CNMP',
#   '中国移动福建公司2023年核心网运维工作台开发研发项目',
#   '王彬彬',
#   '未开始',
#   '福建',
#   '移动',
#   '福建移动'),
#  ('云网运营事业部',
#   1276,
#   'U-XJYD-CNMP',
#   '新疆某单位技术支撑服务040113采购项目框架合同',
#   '廖燕芳',
#   '未开始',
#   '新疆',
#   '移动',
#   '新建移动'),
#  ('云网运营事业部',
#   1310,
#   'U-LTJT-GZQD',
#   '2023年联通研究院感知驱动的场景化智能服务工具开发',
#   '王金树',
#   '进行中',
#   '北京',
#   '联通',
#   '联通集团'),
#  ('云网运营事业部',
#   1312,
#   'U-LTJT-LLPJ',
#   '2023年中国联通研究院基于知识图谱的传输网链路路由拼接技术及平台开发',
#   '王金树',
#   '未开始',
#   '',
#   '联通',
#   '联通集团')]

# %%
for project_info in project_list:
		project_commit=[]
		print("项目信息",project_info)
# Out:
# 项目信息 ('云网运营事业部', 188, 'oasinterface_nx', '宁夏集中操作维护OAS 接口服务提供', '田东飞', '未开始', None, None, None)
# 项目信息 ('云网运营事业部', 209, 'jzwh', '宁夏核心网基站维护工具', '田东飞', '未开始', None, None, None)
# 项目信息 ('云网运营事业部', 246, 'ultra-log', '卫通项目二期', '肖森森', '未开始', None, None, None)
# 项目信息 ('云网运营事业部', 334, 'U-XJYD-YWZC', '新疆移动政企运维支撑系统', '王志喜', '进行中', '新疆', '移动', '新疆移动')
# 项目信息 ('云网运营事业部', 397, 'U-LTJT-TLXY', '联通集团网研院天猎星云业务分析系统', '王金树', '进行中', '集团', '联通', '集团联通')
# 项目信息 ('云网运营事业部', 695, 'U-LTJT-TSGZ', '联通集团网研院用户级感知评价及预警平台', '王金树', '进行中', '集团', '联通', '集团联通')
# 项目信息 ('云网运营事业部', 700, 'U-LTJT-TXYJ', '联通集团网研院移网投诉分析支撑系统', '王金树', '进行中', '集团', '联通', '集团联通')
# 项目信息 ('云网运营事业部', 839, 'U-GD-CNMP', '广播电视集团核心网运维工作台', '陈思良', '已完成', '集团', '广电', '集团广电')
# 项目信息 ('云网运营事业部', 988, 'U-GZYD-SJWG', '贵州移动数据网管系统', '杨新', '维保阶段', '贵州', '移动', '贵州移动')
# 项目信息 ('云网运营事业部', 989, 'U-YDJT-GBAMS', '移动集团核心网工作台主动监测系统', '李远', '进行中', '集团', '移动', '集团移动')
# 项目信息 ('云网运营事业部', 990, 'U-HBYD-CNMP', '河北移动核心网运维工作台', '刘龙', '进行中', '河北', '移动', '河北移动')
# 项目信息 ('云网运营事业部', 992, 'U-GZYD-SJGXPT', '贵州移动数据共享平台', '杨新', '维保阶段', '贵州', '移动', '贵州移动')
# 项目信息 ('云网运营事业部', 998, 'U-GZYD-CDNGZT', '贵州移动CDN运维工作台', '陈雪梅', '进行中', '贵州', '移动', '贵州移动')
# 项目信息 ('云网运营事业部', 999, 'U-GZDX-YWZHWG', '贵州电信业务平台综合网管', '陈亚琴', '维保阶段', '贵州', '电信', '贵州电信')
# 项目信息 ('云网运营事业部', 1006, 'U-GXYD-IPDIW', '广西移动IP运维工作台', '彭新勇', '进行中', '广西', '移动', '广西移动')
# 项目信息 ('云网运营事业部', 1011, 'U-GXYD-IPNMS', '广西移动IP网管', '彭新勇', '维保阶段', '广西', '移动', '广西移动')
# 项目信息 ('云网运营事业部', 1017, 'U-GXYD-SCREEN', '广西移动监控可视化大屏', '邓蔓', '进行中', '广西', '移动', '广西移动')
# 项目信息 ('云网运营事业部', 1019, 'U-GXYD-PONNMS', '广西移动PON性能分析系统', '彭新勇', '进行中', '广西', '移动', '广西移动')
# 项目信息 ('云网运营事业部', 1023, 'U-GXYD-IQA', '广西移动家宽用户画像', '邓蔓', '进行中', '广西', '移动', '广西移动')
# 项目信息 ('云网运营事业部', 1025, 'U-HIYD-IPDIW', '海南移动IP运维工作台', '王英洁', '进行中', '海南', '移动', '海南移动')
# 项目信息 ('云网运营事业部', 1027, 'U-GSYD-ITDIW', '甘肃移动IT运维工作台', '顾斌', '进行中', '甘肃', '移动', '甘肃移动')
# 项目信息 ('云网运营事业部', 1031, 'U-YNYD-IPDIW', '云南移动IP运维工作台', '李国华', '进行中', '云南', '移动', '云南移动')
# 项目信息 ('云网运营事业部', 1036, 'U-YNYD-SJWG', '云南移动数据网OMC系统', '李国华', '维保阶段', '云南', '移动', '云南移动')
# 项目信息 ('云网运营事业部', 1040, 'U-YNYD-CNMP', '云南移动配置管理系统', '吴梓良', '进行中', '云南', '移动', '云南移动')
# 项目信息 ('云网运营事业部', 1042, 'U-YNYD-JZXN', '云南移动家宽性能分析系统', '陈海林1', '进行中', '云南', '移动', '云南移动')
# 项目信息 ('云网运营事业部', 1044, 'U-HBYD-IPDIW', '湖北移动IP运维工作台', '陈源', '进行中', '湖北', '移动', '湖北移动')
# 项目信息 ('云网运营事业部', 1047, 'U-HBYD-SJWG', '湖北移动数据网管', '陈源', '进行中', '湖北', '移动', '湖北移动')
# 项目信息 ('云网运营事业部', 1049, 'U-HBYD-JZXN', '湖北移动家宽性能分析系统', '陈源', '进行中', '湖北', '移动', '湖北移动')
# 项目信息 ('云网运营事业部', 1050, 'U-SNYD-SJWG', '陕西移动数据网管', '卫金龙', '维保阶段', '陕西', '移动', '陕西移动')
# 项目信息 ('云网运营事业部', 1051, 'U-SXYD-IPDIW', '山西移动IP运维工作台', '李峥', '进行中', '山西', '移动', '山西移动')
# 项目信息 ('云网运营事业部', 1052, 'U-SXYD-CNMP', '山西移动核心网运维工作台', '李峥', '进行中', '山西', '移动', '山西移动')
# 项目信息 ('云网运营事业部', 1056, 'U-SXYD-SJWG', '山西移动数据网管', '李峥', '维保阶段', '山西', '移动', '山西移动')
# 项目信息 ('云网运营事业部', 1060, 'U-XJDX-YWZDH', '新疆电信运维自动化平台', '马玲丽', '维保阶段', '新疆', '电信', '新疆电信')
# 项目信息 ('云网运营事业部', 1063, 'U-NXYD-ITOMC', '宁夏移动ITOMC系统', '吴涛', '进行中', '宁夏', '移动', '宁夏移动')
# 项目信息 ('云网运营事业部', 1064, 'U-NXYD-JZCZ', '宁夏移动集中操作维护系统', '吴涛', '进行中', '宁夏', '移动', '宁夏移动')
# 项目信息 ('云网运营事业部', 1066, 'U-CQYD-PZGL', '重庆移动局数据配置管理系统', '金雯', '进行中', '重庆', '移动', '重庆移动')
# 项目信息 ('云网运营事业部', 1071, 'U-NMDX-SJGXPT', '内蒙古电信数据共享平台', '杨新', '维保阶段', '内蒙古', '电信', '内蒙古电信')
# 项目信息 ('云网运营事业部', 1073, 'U-LNYD-JZXN', '辽宁移动集中性能管理系统', '杜洋', '进行中', '辽宁', '移动', '辽宁移动')
# 项目信息 ('云网运营事业部', 1075, 'U-LNYD-YWZDH', '辽宁移动运维自动化系统', '曲直', '进行中', '辽宁', '移动', '辽宁移动')
# 项目信息 ('云网运营事业部', 1076, 'U-DXJT-ZNWG', '电信集团智能网管', '张淼伟', '维保阶段', '北京', '电信', '电信集团')
# 项目信息 ('云网运营事业部', 1078, 'U-BJYD-WJZZL', '北京移动伪基站源头治理系统', '黄剑锋', '维保阶段', '北京', '移动', '北京移动')
# 项目信息 ('云网运营事业部', 1081, 'U-BJYD-CNMP', '北京移动核心网运维工作台', '李远', '进行中', '北京', '移动', '北京移动')
# 项目信息 ('云网运营事业部', 1084, 'U-HBYD-IPMAN', '湖北移动IP地址管理', '陈源', '进行中', '湖北', '移动', '湖北移动')
# 项目信息 ('云网运营事业部', 1085, 'U-HIYD-IPMAN', '海南移动IP地址管理', '王英洁', '进行中', '海南', '移动', '海南移动')
# 项目信息 ('云网运营事业部', 1086, 'U-GXYD-IPMAN', '广西移动IP地址管理', '彭新勇', '进行中', '广西', '移动', '广西移动')
# 项目信息 ('云网运营事业部', 1155, 'U-HNYD-IPDIW', '湖南移动IP运维工作台', '王志防', '进行中', '湖南', '移动', '湖南移动')
# 项目信息 ('云网运营事业部', 1165, 'U-HIYD-CNMP', '海南移动核心网运维工作台', '王英洁', '进行中', '海南', '移动', '海南移动')
# 项目信息 ('云网运营事业部', 1194, 'U-LTJT-CNDL', '2023年中国联通研究院算网网络专线', '王金树', '进行中', '中国', '联通', '研究院')
# 项目信息 ('云网运营事业部', 1196, 'U-ZGGD-IPDIW', '中国广电IP运维工作台', '孙一', '未开始', '中国', '广电', '中国广电')
# 项目信息 ('云网运营事业部', 1198, 'U-LNYD-ZLGL', '辽宁移动质量管理中心项目', '杜洋', '未开始', '辽宁', '移动', '辽宁移动')
# 项目信息 ('云网运营事业部', 1274, 'U-YDJT-CNMP', '中国移动集团核心网工作台支撑服务项目 (集团)', '左战辉', '未开始', '北京', '移动', '中国移动')
# 项目信息 ('云网运营事业部', 1275, 'U-FJYD-CNMP', '中国移动福建公司2023年核心网运维工作台开发研发项目', '王彬彬', '未开始', '福建', '移动', '福建移动')
# 项目信息 ('云网运营事业部', 1276, 'U-XJYD-CNMP', '新疆某单位技术支撑服务040113采购项目框架合同', '廖燕芳', '未开始', '新疆', '移动', '新建移动')
# 项目信息 ('云网运营事业部', 1310, 'U-LTJT-GZQD', '2023年联通研究院感知驱动的场景化智能服务工具开发', '王金树', '进行中', '北京', '联通', '联通集团')
# 项目信息 ('云网运营事业部', 1312, 'U-LTJT-LLPJ', '2023年中国联通研究院基于知识图谱的传输网链路路由拼接技术及平台开发', '王金树', '未开始', '', '联通', '联通集团')

# %%
p_perform = get_project_performance(project_info[1])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 p_perform = get_project_performance(project_info[1])
#
# File ~/Desktop/pypro/khan_dev_data.py:221, in get_project_performance(projectID)
#     219 def get_project_performance(projectID):
#     220     conn = pymysql.connect(**conn_khan)
# --> 221     conn_loc = pymysql.connect(**conn_local)
#     222     project_info = {}
#     223     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     350     self._sock = None
#     351 else:
# --> 352     self.connect()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:636, in Connection.connect(self, sock)
#     633 self._next_seq_id = 0
#     635 self._get_server_information()
# --> 636 self._request_authentication()
#     638 if self.sql_mode is not None:
#     639     c = self.cursor()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/connections.py:933, in Connection._request_authentication(self)
#     931 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     932 if self._auth_plugin_name == "caching_sha2_password":
# --> 933     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     934 elif self._auth_plugin_name == "sha256_password":
#     935     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/_auth.py:265, in caching_sha2_password_auth(conn, pkt)
#     262     if DEBUG:
#     263         print(conn.server_public_key.decode("ascii"))
# --> 265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
#     266 pkt = _roundtrip(conn, data)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pymysql/_auth.py:143, in sha2_rsa_encrypt(password, salt, public_key)
#     138 """Encrypt password with salt and public_key.
#     139
#     140 Used for sha256_password and caching_sha2_password.
#     141 """
#     142 if not _have_cryptography:
# --> 143     raise RuntimeError(
#     144         "'cryptography' package is required for sha256_password or caching_sha2_password auth methods"
#     145     )
#     146 message = _xor_password(password + b"\0", salt)
#     147 rsa_key = serialization.load_pem_public_key(public_key, default_backend())
#
# RuntimeError: 'cryptography' package is required for sha256_password or caching_sha2_password auth methods
